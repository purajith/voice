# %%
import keras
import nltk
import pickle
import json
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation
import random
import datetime
from googlesearch import *
import webbrowser
import requests
from pycricbuzz import Cricbuzz
import billboard
import time
from pygame import mixer
import COVID19Py
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
words=[]
classes=[]
documents=[]
ignore=['?','!',',',"'s"]

data_file=open('intents.json').read()
intents=json.loads(data_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        w=nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))
        
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
            
words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore]
words=sorted(list(set(words)))
classes=sorted(list(set(classes)))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
#training data
training=[]
output_empty=[0]*len(classes)

for doc in documents:
    bag=[]
    pattern=doc[0]
    pattern=[ lemmatizer.lemmatize(word.lower()) for word in pattern ]
    
    for word in words:
        if word in pattern:
            bag.append(1)
        else:
            bag.append(0)
    output_row=list(output_empty)
    output_row[classes.index(doc[1])]=1
    
    training.append([bag,output_row])
    
random.shuffle(training)
training=np.array(training)  
X_train=list(training[:,0])
y_train=list(training[:,1])
# Out:
# C:\Users\purajith\AppData\Local\Temp\ipykernel_15432\3338439442.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training=np.array(training)

# %%
#Model
model=Sequential()
model.add(Dense(128,activation='relu',input_shape=(len(X_train[0]),)))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(y_train[0]),activation='softmax'))

adam=keras.optimizers.Adam(0.001)
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])
#model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)
weights=model.fit(np.array(X_train),np.array(y_train),epochs=200,batch_size=10,verbose=1)    
model.save('mymodel.h5',weights)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 0s 1ms/step - loss: 3.4201 - accuracy: 0.0354
# Epoch 2/200
# 12/12 [==============================] - 0s 1ms/step - loss: 3.3930 - accuracy: 0.0265
# Epoch 3/200
# 12/12 [==============================] - 0s 1ms/step - loss: 3.3746 - accuracy: 0.0531
# Epoch 4/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.3538 - accuracy: 0.0973
# Epoch 5/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.3137 - accuracy: 0.1593
# Epoch 6/200
# 12/12 [==============================] - 0s 1ms/step - loss: 3.3331 - accuracy: 0.0796
# Epoch 7/200
# 12/12 [==============================] - 0s 1ms/step - loss: 3.2821 - accuracy: 0.0885
# Epoch 8/200
# 12/12 [==============================] - 0s 1ms/step - loss: 3.2324 - accuracy: 0.1504
# Epoch 9/200
# 12/12 [==============================] - ETA: 0s - loss: 3.2061 - accuracy: 0.10 - 0s 1ms/step - loss: 3.2185 - accuracy: 0.1239
# Epoch 10/200
# 12/12 [==============================] - 0s 1ms/step - loss: 3.1751 - accuracy: 0.0973
# Epoch 11/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.1397 - accuracy: 0.1150
# Epoch 12/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0408 - accuracy: 0.1239
# Epoch 13/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0048 - accuracy: 0.1681
# Epoch 14/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9126 - accuracy: 0.2124
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8167 - accuracy: 0.2566
# Epoch 16/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7607 - accuracy: 0.1858
# Epoch 17/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6954 - accuracy: 0.3186
# Epoch 18/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5887 - accuracy: 0.3628
# Epoch 19/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5067 - accuracy: 0.3009
# Epoch 20/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4675 - accuracy: 0.3186
# Epoch 21/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2836 - accuracy: 0.3982
# Epoch 22/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2439 - accuracy: 0.3982
# Epoch 23/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1248 - accuracy: 0.4159
# Epoch 24/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0900 - accuracy: 0.4336
# Epoch 25/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9360 - accuracy: 0.4867
# Epoch 26/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9157 - accuracy: 0.4690
# Epoch 27/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8512 - accuracy: 0.4867
# Epoch 28/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6957 - accuracy: 0.5398
# Epoch 29/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7024 - accuracy: 0.5221
# Epoch 30/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5923 - accuracy: 0.5398
# Epoch 31/200
# 12/12 [==============================] - 0s 1ms/step - loss: 1.4619 - accuracy: 0.5752
# Epoch 32/200
# 12/12 [==============================] - 0s 1ms/step - loss: 1.4696 - accuracy: 0.6018
# Epoch 33/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5255 - accuracy: 0.5664
# Epoch 34/200
# 12/12 [==============================] - ETA: 0s - loss: 1.2653 - accuracy: 0.70 - 0s 2ms/step - loss: 1.3569 - accuracy: 0.6106
# Epoch 35/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3289 - accuracy: 0.6283
# Epoch 36/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3025 - accuracy: 0.6372
# Epoch 37/200
# 12/12 [==============================] - 0s 1ms/step - loss: 1.2372 - accuracy: 0.6814
# Epoch 38/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1984 - accuracy: 0.6460
# Epoch 39/200
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0962 - accuracy: 0.6903
# Epoch 40/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0600 - accuracy: 0.7434
# Epoch 41/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1194 - accuracy: 0.6903
# Epoch 42/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0002 - accuracy: 0.7345
# Epoch 43/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9256 - accuracy: 0.7345
# Epoch 44/200
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0046 - accuracy: 0.7257
# Epoch 45/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8796 - accuracy: 0.7080
# Epoch 46/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8717 - accuracy: 0.7522
# Epoch 47/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8395 - accuracy: 0.7699
# Epoch 48/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9613 - accuracy: 0.7345
# Epoch 49/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9821 - accuracy: 0.7257
# Epoch 50/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8663 - accuracy: 0.6991
# Epoch 51/200
# 12/12 [==============================] - ETA: 0s - loss: 0.8480 - accuracy: 0.90 - 0s 2ms/step - loss: 0.7670 - accuracy: 0.8142
# Epoch 52/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7057 - accuracy: 0.8142
# Epoch 53/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7898 - accuracy: 0.7522
# Epoch 54/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6918 - accuracy: 0.7876
# Epoch 55/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7022 - accuracy: 0.7434
# Epoch 56/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6571 - accuracy: 0.7965
# Epoch 57/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6214 - accuracy: 0.7611
# Epoch 58/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7077 - accuracy: 0.7522
# Epoch 59/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6476 - accuracy: 0.8319
# Epoch 60/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4884 - accuracy: 0.8496
# Epoch 61/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6079 - accuracy: 0.8496
# Epoch 62/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5466 - accuracy: 0.8673
# Epoch 63/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5700 - accuracy: 0.8230
# Epoch 64/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5709 - accuracy: 0.8230
# Epoch 65/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6960 - accuracy: 0.8053
# Epoch 66/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4827 - accuracy: 0.8496
# Epoch 67/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5749 - accuracy: 0.7876
# Epoch 68/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.8584
# Epoch 69/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.8850
# Epoch 70/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4713 - accuracy: 0.8496
# Epoch 71/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5425 - accuracy: 0.8142
# Epoch 72/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8761
# Epoch 73/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4364 - accuracy: 0.8850
# Epoch 74/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4825 - accuracy: 0.8496
# Epoch 75/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.8850
# Epoch 76/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.9027
# Epoch 77/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4520 - accuracy: 0.8673
# Epoch 78/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5210 - accuracy: 0.8319
# Epoch 79/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.8850
# Epoch 80/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.9204
# Epoch 81/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4167 - accuracy: 0.9027
# Epoch 82/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8938
# Epoch 83/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4832 - accuracy: 0.8584
# Epoch 84/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3980 - accuracy: 0.8407
# Epoch 85/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3667 - accuracy: 0.8938
# Epoch 86/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3291 - accuracy: 0.9292
# Epoch 87/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.9469
# Epoch 88/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.9204
# Epoch 89/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.9292
# Epoch 90/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2973 - accuracy: 0.9292
# Epoch 91/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.9204
# Epoch 92/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2927 - accuracy: 0.8938
# Epoch 93/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8850
# Epoch 94/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3366 - accuracy: 0.8938
# Epoch 95/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3750 - accuracy: 0.8850
# Epoch 96/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3445 - accuracy: 0.8761
# Epoch 97/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2932 - accuracy: 0.9292
# Epoch 98/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3083 - accuracy: 0.9115
# Epoch 99/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3034 - accuracy: 0.9204
# Epoch 100/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3150 - accuracy: 0.9027
# Epoch 101/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.8938
# Epoch 102/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3151 - accuracy: 0.9027
# Epoch 103/200
# 12/12 [==============================] - ETA: 0s - loss: 0.1893 - accuracy: 0.90 - 0s 2ms/step - loss: 0.3277 - accuracy: 0.8938
# Epoch 104/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2069 - accuracy: 0.9558
# Epoch 105/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3084 - accuracy: 0.9381
# Epoch 106/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8673
# Epoch 107/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3011 - accuracy: 0.8584
# Epoch 108/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3040 - accuracy: 0.9204
# Epoch 109/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2776 - accuracy: 0.9027
# Epoch 110/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2996 - accuracy: 0.8938
# Epoch 111/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3248 - accuracy: 0.8938
# Epoch 112/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3047 - accuracy: 0.8850
# Epoch 113/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2819 - accuracy: 0.9292
# Epoch 114/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2407 - accuracy: 0.9292
# Epoch 115/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2815 - accuracy: 0.8850
# Epoch 116/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.9292
# Epoch 117/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2867 - accuracy: 0.9115
# Epoch 118/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2770 - accuracy: 0.9204
# Epoch 119/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9735
# Epoch 120/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1807 - accuracy: 0.9558
# Epoch 121/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2058 - accuracy: 0.9381
# Epoch 122/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.9469
# Epoch 123/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2181 - accuracy: 0.9292
# Epoch 124/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3204 - accuracy: 0.9027
# Epoch 125/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3318 - accuracy: 0.8761
# Epoch 126/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1732 - accuracy: 0.9469
# Epoch 127/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.9115
# Epoch 128/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2243 - accuracy: 0.9292
# Epoch 129/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2038 - accuracy: 0.9381
# Epoch 130/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9115
# Epoch 131/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2770 - accuracy: 0.9292
# Epoch 132/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.8584
# Epoch 133/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2025 - accuracy: 0.9469
# Epoch 134/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.9115
# Epoch 135/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.9646
# Epoch 136/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2143 - accuracy: 0.9292
# Epoch 137/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1877 - accuracy: 0.9558
# Epoch 138/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2358 - accuracy: 0.9558
# Epoch 139/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2047 - accuracy: 0.9381
# Epoch 140/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2211 - accuracy: 0.9469
# Epoch 141/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.9469
# Epoch 142/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1450 - accuracy: 0.9558
# Epoch 143/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1255 - accuracy: 0.9646
# Epoch 144/200
# 12/12 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 1.00 - 0s 2ms/step - loss: 0.1417 - accuracy: 0.9646
# Epoch 145/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2184 - accuracy: 0.9027
# Epoch 146/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.9823
# Epoch 147/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1619 - accuracy: 0.9558
# Epoch 148/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1318 - accuracy: 0.9469
# Epoch 149/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9469
# Epoch 150/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2712 - accuracy: 0.9204
# Epoch 151/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 0.9558
# Epoch 152/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1699 - accuracy: 0.9381
# Epoch 153/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1410 - accuracy: 0.9823
# Epoch 154/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.9558
# Epoch 155/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9558
# Epoch 156/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9646
# Epoch 157/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1802 - accuracy: 0.9381
# Epoch 158/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1738 - accuracy: 0.9381
# Epoch 159/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2024 - accuracy: 0.9027
# Epoch 160/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2164 - accuracy: 0.9558
# Epoch 161/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1557 - accuracy: 0.9646
# Epoch 162/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9381
# Epoch 163/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1303 - accuracy: 0.9646
# Epoch 164/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1303 - accuracy: 0.9735
# Epoch 165/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.9204
# Epoch 166/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9381
# Epoch 167/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1517 - accuracy: 0.9469
# Epoch 168/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1641 - accuracy: 0.9735
# Epoch 169/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2076 - accuracy: 0.9381
# Epoch 170/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1648 - accuracy: 0.9558
# Epoch 171/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1423 - accuracy: 0.9558
# Epoch 172/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1502 - accuracy: 0.9646
# Epoch 173/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9469
# Epoch 174/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9646
# Epoch 175/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1205 - accuracy: 0.9735
# Epoch 176/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1277 - accuracy: 0.9735
# Epoch 177/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.9646
# Epoch 178/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2009 - accuracy: 0.9381
# Epoch 179/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9912
# Epoch 180/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 0.9735
# Epoch 181/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1717 - accuracy: 0.9381
# Epoch 182/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1217 - accuracy: 0.9646
# Epoch 183/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9558
# Epoch 184/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1250 - accuracy: 0.9558
# Epoch 185/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1365 - accuracy: 0.9735
# Epoch 186/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2095 - accuracy: 0.9381
# Epoch 187/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1436 - accuracy: 0.9735
# Epoch 188/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9381
# Epoch 189/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9115
# Epoch 190/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1641 - accuracy: 0.9381
# Epoch 191/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1141 - accuracy: 0.9646
# Epoch 192/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9646
# Epoch 193/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9558
# Epoch 194/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1256 - accuracy: 0.9558
# Epoch 195/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1225 - accuracy: 0.9735
# Epoch 196/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 1.0000
# Epoch 197/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1176 - accuracy: 0.9646
# Epoch 198/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1160 - accuracy: 0.9646
# Epoch 199/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1302 - accuracy: 0.9823
# Epoch 200/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2252 - accuracy: 0.9027

# %%
from keras.models import load_model
model = load_model('mymodel.h5')
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
#Predict
def clean_up(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=[ lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def create_bow(sentence,words):
    sentence_words=clean_up(sentence)
    bag=list(np.zeros(len(words)))
    
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
    return np.array(bag)

def predict_class(sentence,model):
    p=create_bow(sentence,words)
    res=model.predict(np.array([p]))[0]
 
    threshold=0.8
    results=[[i,r] for i,r in enumerate(res) if r>threshold]
    results.sort(key=lambda x: x[1],reverse=True)
    return_list=[]

    
    for result in results:
        return_list.append({'intent':classes[result[0]],'prob':str(result[1])})
    return return_list

def get_response(return_list,intents_json):
    
    if len(return_list)==0:
        tag='noanswer'
    else:    
        tag=return_list[0]['intent']
    if tag=='datetime':        
        print(time.strftime("%A"))
        print (time.strftime("%d %B %Y"))
        print (time.strftime("%H:%M:%S"))

    if tag=='google':
        query=input('Enter query...')
        chrome_path = r'C:\Program Files (x86)\Google\Chrome\Application\chrome.exe %s'
        for url in search(query, tld="co.in", num=1, stop = 1, pause = 2):
            webbrowser.open("https://google.com/search?q=%s" % query)
    if tag=='weather':
        api_key='987f44e8c16780be8c85e25a409ed07b'
        base_url = "http://api.openweathermap.org/data/2.5/weather?"
        city_name = input("Enter city name : ")
        complete_url = base_url + "appid=" + api_key + "&q=" + city_name
        response = requests.get(complete_url) 
        x=response.json()
        print('Present temp.: ',round(x['main']['temp']-273,2),'celcius ')
        print('Feels Like:: ',round(x['main']['feels_like']-273,2),'celcius ')
        print(x['weather'][0]['main'])
        
    if tag=='news':
        main_url = " http://newsapi.org/v2/top-headlines?country=in&apiKey=bc88c2e1ddd440d1be2cb0788d027ae2"
        open_news_page = requests.get(main_url).json()
        article = open_news_page["articles"]
        results = [] 
          
        for ar in article: 
            results.append([ar["title"],ar["url"]]) 
          
        for i in range(10): 
            print(i + 1, results[i][0])
            print(results[i][1],'\n')
            
    if tag=='cricket':
        c = Cricbuzz()
        matches = c.matches()
        for match in matches:
            print(match['srs'],' ',match['mnum'],' ',match['status'])
    
    if tag=='song':
        chart=billboard.ChartData('hot-100')
        print('The top 10 songs at the moment are:')
        for i in range(10):
            song=chart[i]
            print(song.title,'- ',song.artist)
    if tag=='timer':        
        mixer.init()
        x=input('Minutes to timer..')
        time.sleep(float(x)*60)
        mixer.music.load('Handbell-ringing-sound-effect.mp3')
        mixer.music.play()
        
    if tag=='covid19':
        
        covid19=COVID19Py.COVID19(data_source='jhu')
        country=input('Enter Location...')
        
        if country.lower()=='world':
            latest_world=covid19.getLatest()
            print('Confirmed:',latest_world['confirmed'],' Deaths:',latest_world['deaths'])
        
        else:
                
            latest=covid19.getLocations()
            
            latest_conf=[]
            latest_deaths=[]
            for i in range(len(latest)):
                
                if latest[i]['country'].lower()== country.lower():
                    latest_conf.append(latest[i]['latest']['confirmed'])
                    latest_deaths.append(latest[i]['latest']['deaths'])
            latest_conf=np.array(latest_conf)
            latest_deaths=np.array(latest_deaths)
            print('Confirmed: ',np.sum(latest_conf),'Deaths: ',np.sum(latest_deaths))

    list_of_intents= intents_json['intents']    
    for i in list_of_intents:
        if tag==i['tag'] :
            result= random.choice(i['responses'])
    return result

def response(text):
    return_list=predict_class(text,model)
    response=get_response(return_list,intents)
    return response

while True:
    x=input()
    print(response(x))
    if x.lower() in ['bye','goodbye','get lost','see you']:  
        break

hi

#Self learning
print('Help me Learn?')
tag=input('Please enter general category of your question  ')
flag=-1
for i in range(len(intents['intents'])):
    if tag.lower() in intents['intents'][i]['tag']:
        intents['intents'][i]['patterns'].append(input('Enter your message: '))
        intents['intents'][i]['responses'].append(input('Enter expected reply: '))        
        flag=1

if flag==-1:
    
    intents['intents'].append (
        {'tag':tag,
         'patterns': [input('Please enter your message')],
         'responses': [input('Enter expected reply')]})
    
with open('intents.json','w') as outfile:
    outfile.write(json.dumps(intents,indent=4))
